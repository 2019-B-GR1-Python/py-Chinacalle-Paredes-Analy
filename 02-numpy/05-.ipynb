# %% [markdown]
# ![](https://rockcontent.com/es/wp-content/uploads/2019/02/Formatos-de-imagen-1280x720.png)

# %%
import numpy as np
from scipy import ndimage
from scipy import misc
# Out:
# C:\Users\USRBET\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
mapache = misc.face()
mapache
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
mapache.shape
# Out:
# (768, 1024, 3)

# %%
print(type(mapache))
# Out:
# <class 'numpy.ndarray'>

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(mapache)
plt.show()

# %%
plt.imshow(mapache[::-1])
plt.show()

# %%
intento_1, intento_2 = np.split(mapache,2)

# %%
plt.imshow(intento_1)

# %%
plt.imshow(intento_2)

# %%
plt.imshow(mapache + 215)
plt.show()

# %%
plt.imshow(mapache)
plt.show()

# %%
plt.imshow(mapache[:500,400:])
plt.show()

# %%
arr1, arr2 = np.vsplit(mapache, 2)
arr3, arr4 = np.hsplit(arr1,2)
arr5, arr6 = np.hsplit(arr2,2)
matriz = []

plt.imshow(arr3)
plt.show()

# %%
plt.imshow(arr5)
plt.show()

# %%
mapache.shape
# Out:
# (768, 1024, 3)

# %%
arr1
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[203, 233, 111],
#         [198, 228, 106],
#         [191, 223,  98],
#         ...,
#         [ 24,  36,  16],
#         [ 25,  37,  17],
#         [ 25,  37,  17]],
#
#        [[203, 233, 109],
#         [198, 228, 104],
#         [191, 223,  96],
#         ...,
#         [ 24,  36,  16],
#         [ 25,  37,  17],
#         [ 25,  37,  17]],
#
#        [[195, 225, 101],
#         [194, 226,  99],
#         [193, 225,  98],
# ...

# %%
fig, axs = plt.subplots(2,2)
matriz = []
matriz.append(axs[0,0].imshow(arr3))
matriz.append(axs[0,1].imshow(arr4))
matriz.append(axs[1,0].imshow(arr5))
matriz.append(axs[1,1].imshow(arr6))

plt.show()
